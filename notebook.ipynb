# %%
print("Test ...")
# Out:
# Test ...

# %%
# Create the Spark session via Databricks Connect.
# `spark` is auto-injected in the Databricks web UI, but NOT when running
# locally in VSCode — so we build it here. The Databricks VSCode extension
# supplies the cluster/host/auth via environment variables.
from databricks.connect import DatabricksSession

spark = DatabricksSession.builder.getOrCreate()

# %%
spark.sql("""
SELECT *
FROM nyctaxi.gold.daily_trips_summary
WHERE pickup_date = '2024-01-02'
""")
# Out:
# DataFrame[pickup_date: date, total_trips: bigint, average_passengers: int, average_distance: double, total_fare: double, max_fare: double, min_fare: double, total_revenue: double]

# %%
spark.sql("""
SELECT * FROM nyctaxi.silver.zones LIMIT 5;
""")
# Out:
# DataFrame[location_id: int, borough: string, zone: string, service_zone: string, valid_from: timestamp, valid_to: timestamp]

# %%
path = "abfss://population-data@tokeexternalstorage2026.dfs.core.windows.net/country-data/countries_population.snappy.parquet"

df = spark.read.format("parquet").load(path=path)
df.show()
# Out:
# +----------+--------------------+--------------------+------------+----------+--------------------+----------+--------+---------+-------------+
# |country_id|                name|         nationality|country_code|iso_alpha2|             capital|population|area_km2|region_id|sub_region_id|
# +----------+--------------------+--------------------+------------+----------+--------------------+----------+--------+---------+-------------+
# |       210|           Sri Lanka|          Sri Lankan|         LKA|        LK|Sri Jayawardenapu...|  21323733|   65610|       30|           30|
# |       211|               Sudan|            Sudanese|         SDN|        SD|            Khartoum|  42813238| 1886068|       50|           40|
# |       212|            Suriname|          Surinamese|         SUR|        SR|          Paramaribo|    581372|  163820|       10|           10|
# ...

# %%
spark.sql("""
DELETE FROM nyctaxi.gold.daily_trips_summary
WHERE pickup_date >= '2025-07-01'
""")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.sql("""
SELECT COUNT(*) FROM nyctaxi.gold.daily_trips_summary
WHERE pickup_date >= '2025-07-01'
""")
# Out:
# DataFrame[COUNT(*): bigint]

# %%
spark.sql("DESCRIBE nyctaxi.landing.trips_raw")
# Out:
# DataFrame[col_name: string, data_type: string, comment: string]

# %%
# %sql
ALTER TABLE nyctaxi.landing.trips_raw ALTER COLUMN VendorID TYPE BIGINT;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 global _sqldf
# ----> 2 _sqldf = spark.sql('''ALTER TABLE nyctaxi.landing.trips_raw ALTER COLUMN VendorID TYPE BIGINT''')
#       3 _sqldf
#
# File ~/Codes/Databricks/nyc-taxi/.venv/lib/python3.12/site-packages/pyspark/sql/connect/session.py:909, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     906         _views.append(SubqueryAlias(df._plan, name))
#     908 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 909 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     910 if "sql_command_result" in properties:
#     911     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# ...

# %%
spark.sql("""
ALTER TABLE nyctaxi.landing.trips_raw
SET TBLPROPERTIES ('delta.enableTypeWidening' = 'true');""")
# Out:
# DataFrame[]

# %%
spark.sql("""
ALTER TABLE nyctaxi.landing.trips_raw ALTER COLUMN VendorID TYPE BIGINT;""")
# Out:
# DataFrame[]

# %%
spark.sql("DESCRIBE nyctaxi.landing.trips_raw")
# Out:
# DataFrame[col_name: string, data_type: string, comment: string]

# %%
spark.sql("""ALTER TABLE nyctaxi.landing.trips_raw ALTER COLUMN passenger_count TYPE DOUBLE;""")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 spark.sql("""ALTER TABLE nyctaxi.landing.trips_raw ALTER COLUMN passenger_count TYPE DOUBLE;""")
#
# File ~/Codes/Databricks/nyc-taxi/.venv/lib/python3.12/site-packages/pyspark/sql/connect/session.py:909, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     906         _views.append(SubqueryAlias(df._plan, name))
#     908 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 909 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     910 if "sql_command_result" in properties:
#     911     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File ~/Codes/Databricks/nyc-taxi/.venv/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1617, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
# ...

# %%
# %sql
CREATE OR REPLACE TABLE nyctaxi.landing.trips_raw (
    VendorID BIGINT,
    tpep_pickup_datetime TIMESTAMP_NTZ,
    tpep_dropoff_datetime TIMESTAMP_NTZ,
    passenger_count DOUBLE,
    trip_distance DOUBLE,
    RatecodeID DOUBLE,
    store_and_fwd_flag STRING,
    PULocationID BIGINT,
    DOLocationID BIGINT,
    payment_type LONG,
    fare_amount DOUBLE,
    extra DOUBLE,
    mta_tax DOUBLE,
    tip_amount DOUBLE,
    tolls_amount DOUBLE,
    improvement_surcharge DOUBLE,
    total_amount DOUBLE,
    congestion_surcharge DOUBLE,
    airport_fee DOUBLE,
    cbd_congestion_fee DOUBLE
);
# Out:
# DataFrame[]

# %%
# %sql
CREATE OR REPLACE TABLE nyctaxi.bronze.trips (
    vendor_id INT,
    pickup_datetime TIMESTAMP,
    dropoff_datetime TIMESTAMP,
    passenger_count INT,
    trip_distance DOUBLE,
    rate_code_id INT,
    store_and_fwd_flag STRING,
    pickup_location_id INT,
    dropoff_location_id INT,
    payment_type LONG,
    fare_amount DOUBLE,
    extra DOUBLE,
    mta_tax DOUBLE,
    tip_amount DOUBLE,
    tolls_amount DOUBLE,
    improvement_surcharge DOUBLE,
    total_amount DOUBLE,
    congestion_surcharge DOUBLE,
    airport_fee DOUBLE,
    cbd_congestion_fee DOUBLE,
    processed_timestamp TIMESTAMP
);
# Out:
# DataFrame[]

# %%
# %sql
DESCRIBE nyctaxi.landing.trips_raw;
# Out:
# DataFrame[col_name: string, data_type: string, comment: string]

# %%
# %sql
DESCRIBE nyctaxi.bronze.trips;
# Out:
# DataFrame[col_name: string, data_type: string, comment: string]

# %%
# %sql
DESCRIBE nyctaxi.silver.trips;
# Out:
# DataFrame[col_name: string, data_type: string, comment: string]

# %%
for m in range(12):
    month = f"2023-{(m + 1):02d}"
    df = spark.read.parquet(f"/Volumes/nyctaxi/landing/data_sources/nyctaxi_yellow/trips/{month}/yellow_tripdata_{month}.parquet")
    schema = list(df.schema.fields)
    print(f"PULocationID: {schema[7].dataType} RatecodeID: {schema[5].dataType}")
# Out:
# PULocationID: LongType() RatecodeID: DoubleType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()
# PULocationID: IntegerType() RatecodeID: LongType()

# %%
df.schema.fields[7].dataType
# Out:
# StructField('PULocationID', IntegerType(), True)

# %%
df
# Out:
# DataFrame[VendorID: int, tpep_pickup_datetime: timestamp_ntz, tpep_dropoff_datetime: timestamp_ntz, passenger_count: bigint, trip_distance: double, RatecodeID: bigint, store_and_fwd_flag: string, PULocationID: int, DOLocationID: int, payment_type: bigint, fare_amount: double, extra: double, mta_tax: double, tip_amount: double, tolls_amount: double, improvement_surcharge: double, total_amount: double, congestion_surcharge: double, Airport_fee: double, cbd_congestion_fee: double]

# %%
df.filter("PULocationID IS NULL")
# Out:
# DataFrame[VendorID: int, tpep_pickup_datetime: timestamp_ntz, tpep_dropoff_datetime: timestamp_ntz, passenger_count: bigint, trip_distance: double, RatecodeID: bigint, store_and_fwd_flag: string, PULocationID: int, DOLocationID: int, payment_type: bigint, fare_amount: double, extra: double, mta_tax: double, tip_amount: double, tolls_amount: double, improvement_surcharge: double, total_amount: double, congestion_surcharge: double, Airport_fee: double, cbd_congestion_fee: double]

# %%
display(df.schema)
# Out:
# StructType([StructField('VendorID', IntegerType(), True), StructField('tpep_pickup_datetime', TimestampNTZType(), True), StructField('tpep_dropoff_datetime', TimestampNTZType(), True), StructField('passenger_count', LongType(), True), StructField('trip_distance', DoubleType(), True), StructField('RatecodeID', LongType(), True), StructField('store_and_fwd_flag', StringType(), True), StructField('PULocationID', IntegerType(), True), StructField('DOLocationID', IntegerType(), True), StructField('payment_type', LongType(), True), StructField('fare_amount', DoubleType(), True), StructField('extra', DoubleType(), True), StructField('mta_tax', DoubleType(), True), StructField('tip_amount', DoubleType(), True), StructField('tolls_amount', DoubleType(), True), StructField('improvement_surcharge', DoubleType(), True), StructField('total_amount', DoubleType(), True), StructField('congestion_surcharge', DoubleType(), True), StructField('Airport_fee', DoubleType(), True), StructField('cbd_congest
# ...
