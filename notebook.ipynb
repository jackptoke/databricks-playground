# %%
print("Test ...")
# Out:
# Test ...

# %%
# Create the Spark session via Databricks Connect.
# `spark` is auto-injected in the Databricks web UI, but NOT when running
# locally in VSCode — so we build it here. The Databricks VSCode extension
# supplies the cluster/host/auth via environment variables.
from databricks.connect import DatabricksSession

spark = DatabricksSession.builder.getOrCreate()

# %%
spark.read.table("nyctaxi.gold.daily_trips_summary").show()
# Out:
# +-----------+-----------+------------------+----------------+----------+--------+--------+-------------+
# |pickup_date|total_trips|average_passengers|average_distance|total_fare|max_fare|min_fare|total_revenue|
# +-----------+-----------+------------------+----------------+----------+--------+--------+-------------+
# | 2025-10-21|     136833|                 1|             6.0| 2350599.0|   415.0|  -224.9|   3601238.39|
# | 2025-10-27|     122604|                 1|             7.0| 2174414.0|   563.7|  -450.4|   3297403.41|
# | 2025-10-17|     153567|                 1|             7.0| 3005239.0|   791.2|  -750.0|   4372376.15|
# | 2025-10-20|     116870|                 1|             6.0| 2179493.0|  792.85| -792.85|   3297462.12|
# | 2025-10-18|     152292|                 1|             6.0| 2812930.0|   609.5|  -347.4|   4012295.87|
# | 2025-10-16|     161458|                 1|             6.0| 3251985.0|   557.4|  -250.0|   4729431.62|
# | 2025-10-30|     163577|                 1|             8.0| 2599876.0|   872.4|  -600.0|   3985705.06|
# | 2025-10-01|     135029|                 1|             8.0| 2493363.0|   664.5|  -664.5|   3674490.25|
# | 2025-10-14|     139132|                 1|             5.0| 2702209.0|   642.1|  -642.1|   3979696.85|
# | 2025-10-13|     112005|                 1|             8.0| 2081431.0|   800.0|  -800.0|   3026003.44|
# | 2025-10-04|     147729|                 1|             6.0| 2665825.0|   700.0|  -600.0|   3800808.15|
# | 2025-10-03|     142690|                 1|             6.0| 2658521.0|   675.7|  -488.8|   3882331.26|
# | 2025-10-12|     129982|                 1|             6.0| 2501849.0|   651.0|  -480.0|    3551854.7|
# | 2025-10-07|     134704|                 1|             6.0| 2433425.0|   470.0|  -300.0|   3626990.94|
# | 2025-10-06|     120579|                 1|            10.0| 2326057.0|   650.0|  -650.0|   3414839.67|
# | 2025-10-19|     138473|                 1|            12.0| 2769214.0|  1056.5|  -516.0|   3922876.04|
# | 2025-10-22|     146946|                 1|             4.0| 2554504.0|   483.2|  -396.4|   3903963.92|
# | 2025-10-24|     153910|                 1|            10.0| 2511888.0|   689.0|  -417.4|   3872628.86|
# | 2025-10-09|     162293|                 1|             4.0| 3280110.0|   500.0|  -500.0|   4755461.74|
# | 2025-10-05|     126963|                 1|             6.0| 2590815.0|   635.1|  -635.1|   3654060.95|
# +-----------+-----------+------------------+----------------+----------+--------+--------+-------------+
# only showing top 20 rows
